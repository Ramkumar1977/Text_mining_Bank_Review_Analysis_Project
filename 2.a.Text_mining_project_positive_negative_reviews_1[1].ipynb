# %%
import pandas as pd
import numpy as np

TEXT = pd.read_excel("C:\\Users\\RAMKUMAR\\Desktop\\BankReviews.xlsx")
TEXT
# Out:
#           Date  Stars                                            Reviews  \
# 0   2017-04-10      5  Great job, Wyndham Capital! Each person was pr...
# 1   2017-02-10      5  Matthew Richardson is professional and helpful...
# 2   2017-08-21      5  We had a past experience with Wyndham Mortgage...
# 3   2017-12-17      5  We have been dealing with Brad Thomka from the...
# 4   2016-05-27      5  I can't express how grateful I am for the supp...
# 5   2016-12-20      5  I had the pleasure of working with Wyndham Cap...
# 6   2017-12-17      5  My experience with Mattison was beyond greatly...
# 7   2016-08-16      5  Patrick answered all my questions by email imm...
# 8   2017-09-04      5  I loved working with this group of people! The...
# 9   2016-03-22      5  Great web interface for both the loan applicat...
# 10  2017-04-02      5  Working with Michelle and Wyndham went really ...
# 11  2016-02-06      5  usten Butler brought the humanity and connecti...
# 12  2016-06-11      5  Jay was easy to get a hold of if I had any que...
# 13  2017-03-04      5  If I had a million Friends I would recommend a...
# 14  2016-11-06      5  Chaz was fantastic throughout the entire lendi...
# 15  2016-07-03      5  Austen has been awsome in every step of the wa...
# 16  2016-10-07      5  The salesperson kept pushing a cash out refi o...
# 17  2017-02-24      1  This was the worst experience ever. It was lik...
# 18  2016-03-14      1  A good rate but a very frustrating process, co...
# 19  2017-08-13      1  They were not upfront. Learn from my mistake.....
# 20  2016-06-26      1  Initially, the Mortgage Broker was very friend...
# 21  2016-06-26      1  Initially, the Mortgage Broker was very friend...
# 22  2016-01-15      5  I worked with Kory and Carla at NASB. They wer...
# 23  2017-10-11      5  Kory was by far the best loan officer I have e...
# 24  2016-10-14      5  Expert loan officer, well versed in VA and the...
# 25  2016-01-08      5  The NASB team went above and beyond for me and...
# 26  2016-10-22      5  Dallas Goodlet and his entire team are deservi...
# 27  2017-09-12      5  Comments: To begin my wife and I were at the p...
# 28  2017-05-24      5  Working with Jon was such an amazing experienc...
# 29  2017-05-02      5  NASB was amazing to work with! The pre-approva...
# ..         ...    ...                                                ...
# 475 2017-08-06      5  \r\nJoey was knowledgeable, very accessible an...
# 476 2016-10-29      5  \r\nI was hesitant to use a non-local mortgage...
# 477 2016-12-05      5  \r\nI was hesitant to use a non-local mortgage...
# 478 2017-10-04      5  \r\nSteve got it done when others couldn't. 30...
# 479 2016-08-31      5  \r\nVery professional and customer oriented.\r...
# 480 2017-05-09      5  \r\nSteve was very responsive and patient with...
# 481 2016-10-22      5  \r\nGreat bank with great products.  Easily th...
# 482 2017-09-12      5  \r\nDallas is very experienced and knowledgeab...
# 483 2016-01-23      5  \r\nI was extremely impressed with the proffes...
# 484 2017-09-12      5  \r\nI was extremely impressed with the proffes...
# 485 2017-05-24      5  \r\nRC Malcolm was excellent, he stayed on top...
# 486 2016-10-22      5  \r\nExcellent service . RC stayed on top of ev...
# 487 2017-08-06      5  \r\nThey completed everything on time to get u...
# %%
TEXT.dropna(inplace=True)
TEXT[TEXT['Stars'] != 3]
TEXT['Positively Rated'] = np.where(TEXT['Stars'] > 3, 1, 0)
TEXT.head(10)
# Out:
#         Date  Stars                                            Reviews  \
# 0 2017-04-10      5  Great job, Wyndham Capital! Each person was pr...
# 1 2017-02-10      5  Matthew Richardson is professional and helpful...
# 2 2017-08-21      5  We had a past experience with Wyndham Mortgage...
# 3 2017-12-17      5  We have been dealing with Brad Thomka from the...
# 4 2016-05-27      5  I can't express how grateful I am for the supp...
# 5 2016-12-20      5  I had the pleasure of working with Wyndham Cap...
# 6 2017-12-17      5  My experience with Mattison was beyond greatly...
# 7 2016-08-16      5  Patrick answered all my questions by email imm...
# 8 2017-09-04      5  I loved working with this group of people! The...
# 9 2016-03-22      5  Great web interface for both the loan applicat...
#
#                    BankName  Positively Rated
# 0  Wyndham Capital Mortgage                 1
# 1  Wyndham Capital Mortgage                 1
# 2  Wyndham Capital Mortgage                 1
# 3  Wyndham Capital Mortgage                 1
# 4  Wyndham Capital Mortgage                 1
# 5  Wyndham Capital Mortgage                 1
# 6  Wyndham Capital Mortgage                 1
# 7  Wyndham Capital Mortgage                 1
# 8  Wyndham Capital Mortgage                 1
# 9  Wyndham Capital Mortgage                 1

# %%
TEXT['Positively Rated'].mean()
# Out:
# 0.8118811881188119

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(TEXT['Reviews'], TEXT['Positively Rated'], random_state = 0)

# %%
print('X_train first entry: \n\n', X_train[0])
print('\n\nX_train shape: ', X_train.shape)
# Out:
# X_train first entry:
#
#  Great job, Wyndham Capital! Each person was professional and helped us move through our refinance process smoothly. Thank you!
#
#
# X_train shape:  (378,)

# %%
 X_train[0]
# Out:
# 'Great job, Wyndham Capital! Each person was professional and helped us move through our refinance process smoothly. Thank you!'

# %%
 X_train
# Out:
# 326    \r\nRecently, I successfully financed a home l...
# 394    \r\nMike's knowledge and enthusiasm are eviden...
# 415    \r\nPositive: Completed mortgage refinance red...
# 490    \r\nOur refinance process was a dream once we ...
# 250    \r\nThis was my first home purchas; however, w...
# 276    \r\nStephanie Drewry took such wonderful care ...
# 55     \r\nRitu was a pleasure to work with. She was ...
# 295    \r\nI worked with Steven Castaneda a few years...
# 462    \r\nFast, helpful, best service possible. I he...
# 246    \r\nVery professional yet personable.  Quick t...
# 494    \r\nOur loan officer was happy to communicate ...
# 200    \r\nFast, helpful, best service possible. I he...
# 372    \r\nWas a quick and easy process. They worked ...
# 498    \r\nBuilt new home and wanted to get a small m...
# 52     \r\nThanks to Reliance Capital for helping us ...
# 74     \r\nTeddy represents his company very well. He...
# 26     Dallas Goodlet and his entire team are deservi...
# 377    \r\nOur experience with Tom exceeded expectati...
# 4      I can't express how grateful I am for the supp...
# 320    \r\nI had a great experience working with Adan...
# 229    \r\nIt all started when Bob G ran a credit che...
# 327    \r\nWe are grateful that we came across Adan M...
# 5      I had the pleasure of working with Wyndham Cap...
# 141    \r\nEverything I said about my loan officer ho...
# 428    \r\nNASB was amazing to work with! The pre-app...
# 135    \r\nIt was a pleasure working with Alex Jocovi...
# 196    \r\nRC was excellent to work with!  He is a st...
# 122    \r\nI can't say enough great things about my l...
# 22     I worked with Kory and Carla at NASB. They wer...
# 68     \r\nFrom the very first conversation that I ha...
#                              ...
# 265    \r\nGreat to work with, very responsive to all...
# 72     \r\nIt was fast easy and did not have to leave...
# 333    \r\nIt is simple really. Doing a re-fi is a lo...
# 25     The NASB team went above and beyond for me and...
# 165    \r\nWorking with Jon was such an amazing exper...
# 337    \r\nI have purchased 4 properties in CA in the...
# 488    \r\nBrad was helpful through the entire proces...
# 174    \r\nRob was very helpful in getting this loan ...
# 491    \r\nThe closing process for a VA loan went smo...
# 39     The closing process for a VA loan went smoothl...
# 193    \r\nJoey was very helpful. We appreciated his ...
# 314    \r\nI worked with Anthony M and Ranee M for th...
# 396    \r\nA friend of mine told me that he just refi...
# 88     \r\nWesley White worked tirelessly and patient...
# 472    \r\nI worked with a person name Andrew Leehy. ...
# 70      \r\nVery informative, and responsive\r\n
# 87     \r\nAfter spending 8 months trying to complete...
# 292    \r\nThis is the second time I have worked with...
# 242    \r\nYou can tell about his character and hones...
# 277    \r\nFrom the very beginning, The Lending Tree ...
# 211    \r\nFred was awesome to work with! He is very ...
# 9      Great web interface for both the loan applicat...
# 359    \r\nMarcus was great to work with. Was always ...
# 195    \r\nMy family and I shopped around for home mo...
# 251    \r\nAndy was an incredible resource and guide ...
# 323    \r\nAnthony Marroquin and his team were knowle...
# 192    \r\nVery responsive and worked hard to get us ...
# 117    \r\nOutstanding! My wife and I have had many p...
# 47     What a horrible experience. We have excellent ...
# 172    \r\nGreat website, knowledgeable, responsive a...
# Name: Reviews, Length: 378, dtype: object

# %%
# CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer

vect = CountVectorizer().fit(X_train)

# %%
vect.get_feature_names()[::3000]
# Out:
# ['10']

# %%
len(vect.get_feature_names())
# Out:
# 2392

# %%
# transform the documents in the training data to a document-term matrix
X_train_vectorized = vect.transform(X_train)
X_train_vectorized
# Out:
# <378x2392 sparse matrix of type '<class 'numpy.int64'>'
# 	with 19722 stored elements in Compressed Sparse Row format>

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train_vectorized, y_train)
# Out:
# C:\Users\RAMKUMAR\Documents\Python Scripts\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
from sklearn.metrics import roc_auc_score

predictions = model.predict(vect.transform(X_test))

print('AUC: ', roc_auc_score(y_test, predictions))
# Out:
# AUC:  0.7833649588867805

# %%
# get the feature names as numpy array
feature_names = np.array(vect.get_feature_names())

# Sort the coefficients from the model
sorted_coef_index = model.coef_[0].argsort()

# Find the 10 smallest and 10 largest coefficients
# The 10 largest coefficients are being indexed using [:-11:-1] 
# so the list returned is in order of largest to smallest
print('Smallest Coefs: \n{}\n'.format(feature_names[sorted_coef_index[:10]]))
print('Largest Coefs: \n{}\n'.format(feature_names[sorted_coef_index[:-11:-1]]))
# Out:
# Smallest Coefs:
# ['bad' 'not' 'it' 'phone' 'up' 'this' 'my' 'contacted' 'of' 'they']
#
# Largest Coefs:
# ['with' 'great' 'and' 'helpful' 'he' 'time' 'easy' 'best' 'his'
#  'responsive']

# %%
#Tfidf
from sklearn.feature_extraction.text import TfidfVectorizer

# Fit the TfidfVectorizer to the training data specifiying a minimum document frequency of 5
vect = TfidfVectorizer(min_df = 5).fit(X_train)
len(vect.get_feature_names())
# Out:
# 715

# %%
X_train_vectorized = vect.transform(X_train)

model = LogisticRegression()
model.fit(X_train_vectorized, y_train)
predictions = model.predict(vect.transform(X_test))
print('AUC: ', roc_auc_score(y_test, predictions))
# Out:
# AUC:  0.6764705882352942
# C:\Users\RAMKUMAR\Documents\Python Scripts\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
feature_names = np.array(vect.get_feature_names())

sorted_tfidf_index = X_train_vectorized.max(0).toarray()[0].argsort()

print('Smallest Tfidf: \n{}\n'.format(feature_names[sorted_tfidf_index[:10]]))
print('Largest Tfidf: \n{}\n'.format(feature_names[sorted_tfidf_index[:-11:-1]]))
# Out:
# Smallest Tfidf:
# ['read' 'old' 'weekends' 'tried' 'however' '25' 'pros' 'types' 'versus'
#  'agreed']
#
# Largest Tfidf:
# ['bad' 'informative' 'smooth' 'great' 'timely' 'customer' 'awesome'
#  'buyers' 'chris' 'good']

# %%
sorted_coef_index = model.coef_[0].argsort()

print('Smallest coef: \n{}\n'.format(feature_names[sorted_coef_index[:10]]))
print('Largest coef: \n{}\n'.format(feature_names[sorted_coef_index[:-11:-1]]))
# Out:
# Smallest coef:
# ['not' 'that' 'they' 'this' 'bad' 'of' 'poor' 'which' 'credit' 'contacted']
#
# Largest coef:
# ['and' 'with' 'great' 'he' 'always' 'time' 'team' 'his' 'work' 'best']

# %%
# These reviews are treated the same by our current model

print(model.predict(vect.transform(['Not an issue, phone is working', 
                                   'an issue, phone is not working'])))
# Out:
# [1 1]

# %%
# n-grams
# Fit the CountVectorizer to the training data specifiying a minimum 
# document frequency of 5 and extracting 1-grams and 2-grams
vect = CountVectorizer(min_df = 5, ngram_range = (1,2)).fit(X_train)
X_train_vectorized = vect.transform(X_train)
len(vect.get_feature_names())
# Out:
# 1476

# %%
model = LogisticRegression()
model.fit(X_train_vectorized, y_train)

predictions = model.predict(vect.transform(X_test))
print('AUC: ', roc_auc_score(y_test, predictions))
# Out:
# AUC:  0.7980708412397217
# C:\Users\RAMKUMAR\Documents\Python Scripts\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
feature_names = np.array(vect.get_feature_names())
sorted_coef_index = model.coef_[0].argsort()

print('Smallest Coef: \n{}\n'.format(feature_names[sorted_coef_index][:10]))
print('Largest Coef: \n{}\n'.format(feature_names[sorted_coef_index][:-11:-1]))
# Out:
# Smallest Coef:
# ['bad' 'not' 'it' 'phone' 'my' 'this' 'of' 'contacted' 'up' 'previous']
#
# Largest Coef:
# ['with' 'great' 'and' 'helpful' 'he' 'time' 'best' 'his' 'responsive'
#  'easy']

# %%
print(model.predict(vect.transform(['not an issue, phone is working',
                                   'an issue, phone is not working'])))
# Out:
# [1 1]

# %%
TEXT.dropna(inplace=True)
TEXT =TEXT[TEXT['Stars'] == 1]
TEXT
# Out:
#           Date  Stars                                            Reviews  \
# 17  2017-02-24      1  This was the worst experience ever. It was lik...
# 18  2016-03-14      1  A good rate but a very frustrating process, co...
# 504  North American Savings Bank                 0
#
# [95 rows x 5 columns]

# %%
TEXT.Reviews
# Out:
# 17     This was the worst experience ever. It was lik...
# 18     A good rate but a very frustrating process, co...
# 19     They were not upfront. Learn from my mistake.....
# 20     Initially, the Mortgage Broker was very friend...
# 21     Initially, the Mortgage Broker was very friend...
# 39     The closing process for a VA loan went smoothl...
# 40     Miserable experience. They screwed up everythi...
# 41     Our loan officer was happy to communicate befo...
# 42     Started refinance with Nick things were going ...
# 43     This loan started off quite well. Our rep, Don...
# 44     This Lender contacted my previous phone number...
# 45     I never write reviews but had to this time to ...
# 46     It all started when Bob G ran a credit check w...
# 47     What a horrible experience. We have excellent ...
# 48     Rep was extremely professional, friendly, and ...
# 49     I was working with a loan consultant from NASB...
# 90     \r\nBuyer beware!! To make it short and sweet,...
# 91     \r\nThe team was not aware of some critical in...
# 92     \r\nIn response to previous review, Greg Belle...
# 93     \r\nIf you use Reliance First Capitol...DO NOT...
# 94     \r\nReliance First Capital was very profession...
# 95     \r\nI thought they seemed very nice at first. ...
# 96     \r\nThe experience with Reliance was extremely...
# 97     \r\nPerson with whom I spoke kept interrupting...
# 98     \r\nBased on results I have to give 1 star. My...
# 99     \r\nMonths after I spoke to one person at Amer...
# 100    \r\n Lisa Podorson has set my closing date thr...
# 101    \r\nWorst lending experience of my life. My po...
# 102    \r\nI feel they made promises that they could ...
# 103    \r\nI had an awful experience with Reliance wh...
#                              ...
# 405    \r\nUnfortunately we were dealing with an agen...
# 406    \r\nAdam and his team apparently do not commun...
# 407    \r\nWhile William was fine, my loan officer, a...
# 408    \r\nLending tree matching me up with companies...
# 409    \r\nArbor Mortgage failed me in more ways too ...
# 410    \r\nI was contacted via email by Jody Martin t...
# 411    \r\nAweful experience in terms of service, fol...
# 412    \r\nWas not able to provide a viable product f...
# 413    \r\nCalled me after 60 seconds of submitting m...
# 414    \r\nI spoke to this lender for quite some time...
# 415    \r\nPositive: Completed mortgage refinance red...
# 416    \r\nI tried emailing the lender, and it got se...
# 417    \r\nThey called me and asked about the city in...
# 418    \r\nI would not recommend this mortgage compan...
# 419    \r\nI am new to home buying. Before I make suc...
# 420    \r\nI was "pre-approved" by Guaranteed Rate af...
# 491    \r\nThe closing process for a VA loan went smo...
# 492    \r\nMiserable experience. They screwed up ever...
# 493    \r\nOur loan officer was happy to communicate ...
# 494    \r\nOur loan officer was happy to communicate ...
# 495    \r\nStarted refinance with Nick things were go...
# 496    \r\ncan someone explain why the APR is more th...
# 497    \r\nThis loan started off quite well. Our rep,...
# 498    \r\nBuilt new home and wanted to get a small m...
# 499    \r\nThis Lender contacted my previous phone nu...
# 500    \r\nI never write reviews but had to this time...
# 501    \r\nIt all started when Bob G ran a credit che...
# 502    \r\nWhat a horrible experience. We have excell...
# 503    \r\nRep was extremely professional, friendly, ...
# 504    \r\nI was working with a loan consultant from ...
# Name: Reviews, Length: 95, dtype: object
